# %%
import pandas as pd

# %%
df = pd.read_csv("data/processed/all_apartment_data.csv")
df
# Out:
#       Unnamed: 0                                               urls  \
# 0              0  https://housinganywhere.com/room/ut1460416/gb/...
# 1              1  https://housinganywhere.com/room/ut1483563/gb/...
# 2              2  https://housinganywhere.com/room/ut1355769/gb/...
# 3              3  https://housinganywhere.com/room/ut1482540/gb/...
# 4              4  https://housinganywhere.com/room/ut1483903/gb/...
# ...          ...                                                ...
# 1693        1693  https://www.rightmove.co.uk/properties/1451690...
# 1694        1694  https://www.rightmove.co.uk/properties/1453973...
# 1695        1695  https://www.rightmove.co.uk/properties/1453973...
# 1696        1696  https://www.rightmove.co.uk/properties/1453973...
# 1697        1697  https://www.rightmove.co.uk/properties/1448565...
#
#                                          address  price_per_month  \
# 0                           Leman Street, London             1660
# ...

# %%
import googlemaps
gmaps = googlemaps.Client(key="AIzaSyAkh5x_zWNFDzRq5tu6taLYn0rawQIt-6E")

# %%
def get_lat_lng(address):
    geocode_result = gmaps.geocode(address)
    lat = None
    lng = None
    print(geocode_result)
    if geocode_result:
        lat = geocode_result[0]['geometry']['location']['lat']
        lng = geocode_result[0]['geometry']['location']['lng']
    return lat, lng

# %%
address = df.copy()

# %%
address = address.loc[0:10]
address["coordinates"] = 0



df["coordinates"] = df.apply(lambda x: gmaps.get_lat_lng(x["address"]), axis=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 df["coordinates"] = 0
# ----> 2 df["coordinates"] = df.apply(lambda x: gmaps.get_lat_lng(x["address"]), axis=1)
#       3 df
#
# File ~/Library/Caches/pypoetry/virtualenvs/homie-0xwZBEtk-py3.11/lib/python3.11/site-packages/pandas/core/frame.py:10347, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10333 from pandas.core.apply import frame_apply
#   10335 op = frame_apply(
#   10336     self,
#   10337     func=func,
#    (...)
#   10345     kwargs=kwargs,
#   10346 )
# > 10347 return op.apply().__finalize__(self, method="apply")
#
# File ~/Library/Caches/pypoetry/virtualenvs/homie-0xwZBEtk-py3.11/lib/python3.11/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
# ...

# %%
df
# Out:
#       Unnamed: 0                                               urls  \
# 0              0  https://housinganywhere.com/room/ut1460416/gb/...
# 1              1  https://housinganywhere.com/room/ut1483563/gb/...
# 2              2  https://housinganywhere.com/room/ut1355769/gb/...
# 3              3  https://housinganywhere.com/room/ut1482540/gb/...
# 4              4  https://housinganywhere.com/room/ut1483903/gb/...
# ...          ...                                                ...
# 1693        1693  https://www.rightmove.co.uk/properties/1451690...
# 1694        1694  https://www.rightmove.co.uk/properties/1453973...
# 1695        1695  https://www.rightmove.co.uk/properties/1453973...
# 1696        1696  https://www.rightmove.co.uk/properties/1453973...
# 1697        1697  https://www.rightmove.co.uk/properties/1448565...
#
#                                          address  price_per_month  \
# 0                           Leman Street, London             1660
# ...
